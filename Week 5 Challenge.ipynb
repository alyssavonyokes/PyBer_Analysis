# %%
 # Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read CSV
got_df = pd.read_csv("Resources/got.csv")
got_df
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
# Create a Series containing the number of times each king was an attacker.

attacker_kings = got_df["attacker_king"].value_counts()
attacker_kings
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
# Create a Series containing the number of times each king was a defender.

defender_kings = got_df["defender_king"].value_counts()
defender_kings
# Out:
# Robb Stark                  14
# Joffrey/Tommen Baratheon    13
# Balon/Euron Greyjoy          4
# Stannis Baratheon            2
# Renly Baratheon              1
# Mance Rayder                 1
# Name: defender_king, dtype: int64

# %%
defender_kings.add(attacker_kings, fill_value=0)
# Out:
# Balon/Euron Greyjoy         11.0
# Joffrey/Tommen Baratheon    27.0
# Mance Rayder                 1.0
# Renly Baratheon              1.0
# Robb Stark                  24.0
# Stannis Baratheon            7.0
# dtype: float64

# %%
# Configure plots and ticks.
